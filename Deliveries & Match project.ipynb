# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
cric_data = pd.read_csv(r'C:\Users\patel d d\Desktop\project python files\deliveries cricket Data.csv')
cric_data
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
cric_data.shape
# Out:
# (179078, 21)

# %%
cric_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
cric_data.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %% [markdown]
# As we can see above, dataset has many missing values so it needs to be handled but in our case its match innegings data so this missing values make sense we will not apply data imputation method on it.

# %%
run_total_match = cric_data.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
run_total_match
# Out:
# match_id  inning  batting_team
# 1         1       Sunrisers Hyderabad            207
#           2       Royal Challengers Bangalore    172
# 2         1       Mumbai Indians                 184
#           2       Rising Pune Supergiant         187
# 3         1       Gujarat Lions                  183
#                                                 ...
# 11413     2       Delhi Capitals                 170
# 11414     1       Delhi Capitals                 155
#           2       Chennai Super Kings            162
# 11415     1       Mumbai Indians                 152
#           2       Chennai Super Kings            157
# Name: total_runs, Length: 1528, dtype: int64

# %%
run_total_match = cric_data.groupby(['match_id','inning','batting_team'])['total_runs'].sum()
winners = run_total_match.groupby('match_id').max()
winners
# Out:
# match_id
# 1        207
# 2        187
# 3        184
# 4        164
# 5        157
#         ...
# 11347    143
# 11412    140
# 11413    171
# 11414    162
# 11415    157
# Name: total_runs, Length: 756, dtype: int64

# %% [markdown]
# * # winner teams

# %%
winner_team = run_total_match.groupby('match_id').idxmax()
winning_team = winner_team.apply(lambda x : x[2])
winning_team
# Out:
# match_id
# 1                Sunrisers Hyderabad
# 2             Rising Pune Supergiant
# 3              Kolkata Knight Riders
# 4                    Kings XI Punjab
# 5        Royal Challengers Bangalore
#                     ...
# 11347          Kolkata Knight Riders
# 11412                 Mumbai Indians
# 11413            Sunrisers Hyderabad
# 11414            Chennai Super Kings
# 11415            Chennai Super Kings
# Name: total_runs, Length: 756, dtype: object

# %%
count_winning_team = winning_team.value_counts()
count_winning_team
fig, ax = plt.subplots(figsize = (12,6))
count_winning_team.plot(kind = 'bar',color = 'skyblue')
plt.xlabel('IPL TEAMS')
plt.ylabel('MATCHES')

plt.title('WINNING TEAM')
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# * # Mumbai indians is max time winner

# %% [markdown]
# * # ORANGE CAPE HOLDER

# %%
max_run = cric_data.groupby('batsman')['total_runs'].sum()
best_batsman = max_run.sort_values(ascending=False)
best_batsman = best_batsman.head(10)
best_batsman

plt.figure(figsize=(10,6))
best_batsman.plot(kind='line',color= 'orange')
plt.xlabel('Batsmans')
plt.ylabel('Total runs')
plt.xticks(rotation=90)
plt.title('Best Batsman by Runs')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # Most successful bowler in term of wicket taker
# * # PURPLE CAPE HOLDER

# %%
wicket_taker = cric_data.groupby('bowler')['player_dismissed'].count()
wicket_taker = wicket_taker.sort_values(ascending=False)
wicket_taker = wicket_taker.head(10)
wicket_taker
plt.figure(figsize=(12,6))
wicket_taker.plot(kind='line',color= 'purple')
plt.xlabel('BOWLER')
plt.ylabel('TOTAL WICKETS')
plt.title('BEST BOWLER IN TERMS OF WICKET TAKEN')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # Top batsmen with highest strike rate

# %%
# strike rate : run / balls 
batsman_stike_rate = cric_data.groupby('batsman')['total_runs'].sum() / cric_data.groupby('batsman')['ball'].sum()
batsman_stike_rate = batsman_stike_rate.sort_values(ascending=False).head(10)
batsman_stike_rate

plt.figure(figsize=(12,6))
batsman_stike_rate.plot(kind='bar',color= 'yellow')
plt.xlabel('BATSMANS')
plt.ylabel('STRIKE RATES')
plt.title('TOP BATSMAN WITH HIGHEST STRIKE RATE')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # EXTRA RUNS conceded by each team

# %%
extra_conceded = cric_data.groupby('bowling_team')['extra_runs'].sum().sort_values(ascending=True)
extra_conceded
plt.figure(figsize=(12,6))
extra_conceded.plot(kind='bar',color= 'green')
plt.xlabel('IPL TEAMS')
plt.ylabel('EXTRA RUNS')
plt.title('EXTRA RUNS CONCEDED BY EACH TEAMS')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # Highest partnership by runs

# %%
partnership = cric_data.groupby(['match_id','batsman','non_striker'])['total_runs'].sum().sort_values(ascending=False).head(10)
partnership
# Out:
# match_id  batsman         non_striker
# 562       AB de Villiers  V Kohli        138
# 620       AB de Villiers  V Kohli        132
# 411       CH Gayle        TM Dilshan     130
# 372       CH Gayle        V Kohli        128
# 296       AC Gilchrist    SE Marsh       126
# 331       DA Warner       NV Ojha        119
# 72        AC Gilchrist    VVS Laxman     116
# 11147     J Bairstow      DA Warner      116
# 363       RG Sharma       HH Gibbs       113
# 36        DA Warner       S Dhawan       105
# Name: total_runs, dtype: int64

# %% [markdown]
# * # Dismissal type by batsman

# %%
Dismissal_type_player = cric_data.groupby(['batsman','dismissal_kind'])['player_dismissed'].count().reset_index()
Dismissal_type_player.pivot(index='batsman',columns = 'dismissal_kind',values = 'player_dismissed')
# Out:
# dismissal_kind  bowled  caught  caught and bowled  hit wicket  lbw  \
# batsman
# A Ashish Reddy     5.0     8.0                NaN         NaN  NaN
# A Chandila         NaN     NaN                NaN         NaN  NaN
# A Chopra           NaN     2.0                NaN         NaN  1.0
# A Choudhary        NaN     1.0                NaN         NaN  NaN
# A Flintoff         NaN     1.0                1.0         NaN  NaN
# ...                ...     ...                ...         ...  ...
# YV Takawale        2.0     4.0                NaN         NaN  2.0
# Yashpal Singh      NaN     4.0                NaN         NaN  NaN
# Younis Khan        1.0     NaN                NaN         NaN  NaN
# Yuvraj Singh      10.0    84.0                2.0         1.0  5.0
# Z Khan             5.0     6.0                1.0         NaN  NaN
#
# dismissal_kind  obstructing the field  retired hurt  run out  stumped
# batsman
# A Ashish Reddy                    NaN           NaN      2.0      NaN
# ...

# %% [markdown]
# * # Analyze powerplay score

# %%
powerplay_score = cric_data[cric_data['over']<= 6].groupby('batting_team')['total_runs'].sum().sort_values(ascending=False)
powerplay_score
plt.figure(figsize=(12,6))
powerplay_score.plot(kind='bar',color= 'PINK')
plt.xlabel('BATTING TEAMS')
plt.ylabel('POWERPLAY TOTAL RUNS')
plt.title('POWERPLAY SCORE')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # Top bowlers in term of economy rate

# %%
bowler_economy = cric_data.groupby('bowler')['total_runs'].sum() / cric_data.groupby('bowler')['over'].sum()
bowler_economy = bowler_economy.sort_values(ascending=False).head(10)
bowler_economy
plt.figure(figsize=(12,6))
bowler_economy.plot(kind='bar',color= 'orange')
plt.xlabel('BOWLER')
plt.ylabel('ECONOMY RATE')
plt.title('TOP BOWLERS IN TERM OF ECONOMY RATE')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # Top 10 fielders in tearms of catches taken

# %%
fielder_catches = cric_data[cric_data['dismissal_kind'] == 'caught' ].groupby(['fielder','dismissal_kind'])['fielder'].count()
fielder_catches = fielder_catches.sort_values(ascending=False).head(10)
fielder_catches
plt.figure(figsize=(12,6))
fielder_catches.plot(kind='bar',color= 'YELLOW')
plt.xlabel('FIELDER')
plt.ylabel('CATCH SCORES')
plt.title('FIELDERS IN TEARMS OF CATCH TAKEN')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# * # MATCH DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
match_data = pd.read_csv(r'C:\Users\patel d d\Desktop\project python files\matches cricket Data.csv')
match_data
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
match_data.shape
# Out:
# (756, 18)

# %%
match_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match_data.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# As we can see above, dataset has many missing values so it needs to be handled but in our case its match innegings data so this missing values make sense we will not apply data imputation method on it.

# %% [markdown]
# * # TEAMS TOSS DECISIONS

# %%
teams_toss_decision = match_data.pivot_table(columns='toss_decision',index='toss_winner',aggfunc='size', fill_value=0)
teams_toss_decision
teams_toss_decision.plot(kind='bar')
plt.figure(figsize=(12, 6))
plt.title('TEAMS TOSS DECISIONS')
plt.xlabel('Teams')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# * # win by max runs margin

# %%
wins_by_run = match_data.groupby('winner')['win_by_runs'].max().sort_values(ascending=False)
wins_by_run
# Out:
# winner
# Mumbai Indians                 146
# Royal Challengers Bangalore    144
# Kolkata Knight Riders          140
# Sunrisers Hyderabad            118
# Kings XI Punjab                111
# Rajasthan Royals               105
# Delhi Daredevils                97
# Chennai Super Kings             97
# Deccan Chargers                 82
# Rising Pune Supergiant          61
# Delhi Capitals                  39
# Pune Warriors                   38
# Rising Pune Supergiants         34
# Kochi Tuskers Kerala            17
# Gujarat Lions                    1
# Name: win_by_runs, dtype: int64

# %% [markdown]
# * # win by wickets

# %%
win_wickets = match_data.groupby('winner')['win_by_wickets'].max().sort_values(ascending=False)
win_wickets
# Out:
# winner
# Chennai Super Kings            10
# Deccan Chargers                10
# Delhi Daredevils               10
# Kings XI Punjab                10
# Rajasthan Royals               10
# Mumbai Indians                 10
# Kolkata Knight Riders          10
# Royal Challengers Bangalore    10
# Sunrisers Hyderabad            10
# Rising Pune Supergiant          9
# Rising Pune Supergiants         9
# Kochi Tuskers Kerala            8
# Delhi Capitals                  7
# Gujarat Lions                   7
# Pune Warriors                   7
# Name: win_by_wickets, dtype: int64

# %% [markdown]
# * # Top player of the match

# %%
top_player_of_match = match_data.groupby(['player_of_match','Season'])['player_of_match'].count()
top_player_of_match = top_player_of_match.sort_values(ascending=False).head(10)
top_player_of_match
# Out:
# player_of_match  Season
# CH Gayle         IPL-2011    6
#                  IPL-2012    5
# V Kohli          IPL-2016    5
# MEK Hussey       IPL-2013    5
# SE Marsh         IPL-2008    5
# AD Russell       IPL-2019    4
# AB de Villiers   IPL-2016    4
# SR Watson        IPL-2008    4
# RG Sharma        IPL-2016    4
# DA Warner        IPL-2015    4
# Name: player_of_match, dtype: int64
